# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image, ImageOps
from wordcloud import WordCloud, STOPWORDS
# %matplotlib inline

# %%
article = wikipedia.page("Python programing language")
print (article.url)
# Out:
# https://en.wikipedia.org/wiki/Python_(programming_language)

# %%
wc = WordCloud().generate(article.content)

# %%
plt.imshow(wc)

# %%
plt.imshow(wc, interpolation="bilinear")

# %%
our_mask = np.array(Image.open('cloud_mask.png'))

# %%
wc = WordCloud(width=1000, height=1000, background_color="white",mask= our_mask , stopwords=STOPWORDS).generate(article.content)

# %%
plt.figure(figsize=(10, 10))
plt.axis("off")
plt.imshow(wc)
